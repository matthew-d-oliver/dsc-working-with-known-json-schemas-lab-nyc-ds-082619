# %% [markdown]
# # Working with Known JSON Schemas - Lab

# %% [markdown]
# ## Introduction
# In this lab you'll practice working with json files whose schema you know beforehand.

# %% [markdown]
# ## Objectives
# You will be able to:
# * Read JSON Documentation Schemas and translate into code
# * Extract data from known json schemas
# * Write data to predefined JSON schemas

# %% [markdown]
# ## Reading a JSON Schema
#
# Here's the JSON schema provided for a section of the NY Times API:
# <img src="images/nytimes_movie_schema.png" width=500>
#
# or a fully expanded view:
#
# <img src="images/nytimes_movie_schema_detailed.png" width=500>
#
# You can more about the documentation [here](https://developer.nytimes.com/docs/movie-reviews-api/1/routes/reviews/%7Btype%7D.json/get).

# %% [markdown]
# You can see that the master structure is a dictionary and has a key named 'response'. This is also a dictionary and has two keys: 'data' and 'meta'. As you continue to examine the schema hierarchy, you'll notice the vast majority in this case are dictionaries.

# %% [markdown]
# ## Loading the Data File
#
# Start by importing the json file. The sample response from the api is stored in a file **ny_times_movies.json**

# %%
ls
# Out:
# CONTRIBUTING.md  index.ipynb  ny_times_movies.json  README.md
# images/          LICENSE.md   output.json

# %%
import json 
f=open('ny_times_movies.json')
data=json.load(f)

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## Loading Specific Data
#
# Create a DataFrame of the major data container within the json file, listed under the 'results' heading in the schema above.

# %%
data.keys()
# Out:
# dict_keys(['status', 'copyright', 'has_more', 'num_results', 'results'])

# %%
df= pd.DataFrame(data['results'])
df.head(10)
# Out:
#                 byline  critics_pick         date_updated  \
# 0           A.O. SCOTT             1  2018-10-17 02:44:23
# 1       BEN KENIGSBERG             1  2018-10-16 11:04:03
# 2          GLENN KENNY             1  2018-10-16 11:04:04
# 3           A.O. SCOTT             0  2018-10-16 16:08:03
# 4       BEN KENIGSBERG             0  2018-10-16 11:04:03
# 5           A.O. SCOTT             1  2018-10-17 02:44:21
# 6          GLENN KENNY             1  2018-10-17 02:44:21
# 7  JEANNETTE CATSOULIS             1  2018-10-17 02:44:20
# 8  JEANNETTE CATSOULIS             1  2018-10-17 02:44:19
# 9       BEN KENIGSBERG             1  2018-10-17 02:44:18
#
#                                      display_title  \
# 0                          Can You Ever Forgive Me
# 1                                       Charm City
# 2  Horn from the Heart: The Paul Butterfield Story
# 3                          The Price of Everything
# 4                                          Impulso
# 5                                        Watergate
# 6                                          Barbara
# 7                                   Over the Limit
# 8                         The Kindergarten Teacher
# 9                                 Classical Period
#
#                                             headline  \
# 0  Review: Melissa McCarthy Is Criminally Good in...
# 1  Review: ‘Charm City’ Vividly Captures the Stre...
# 2  Review: Paul Butterfield’s Story Is Told in ‘H...
# 3  Review: ‘The Price of Everything’ Asks $56 Bil...
# 4  Review: ‘Impulso’ Goes Backstage With a Flamen...
# 5  Review: ‘Watergate’ Shocks Anew With Its True ...
# 6  Review: In ‘Barbara,’ a Fictional Biopic of a ...
# 7    Review: A Russian Gymnast Goes ‘Over the Limit’
# 8  Review: The Disturbing Obsession of ‘The Kinde...
# 9  Review: In ‘Classical Period,’ a Deep Dive — R...
#
#                                                 link mpaa_rating  \
# 0  {'type': 'article', 'url': 'http://www.nytimes...           R
# 1  {'type': 'article', 'url': 'http://www.nytimes...
# 2  {'type': 'article', 'url': 'http://www.nytimes...
# 3  {'type': 'article', 'url': 'http://www.nytimes...
# 4  {'type': 'article', 'url': 'http://www.nytimes...
# 5  {'type': 'article', 'url': 'http://www.nytimes...
# 6  {'type': 'article', 'url': 'http://www.nytimes...
# 7  {'type': 'article', 'url': 'http://www.nytimes...
# 8  {'type': 'article', 'url': 'http://www.nytimes...           R
# 9  {'type': 'article', 'url': 'http://www.nytimes...
#
#                                           multimedia opening_date  \
# 0  {'type': 'mediumThreeByTwo210', 'src': 'https:...   2018-10-19
# 1  {'type': 'mediumThreeByTwo210', 'src': 'https:...   2018-04-22
# 2  {'type': 'mediumThreeByTwo210', 'src': 'https:...   2018-10-19
# 3  {'type': 'mediumThreeByTwo210', 'src': 'https:...   2018-10-19
# 4  {'type': 'mediumThreeByTwo210', 'src': 'https:...         None
# 5  {'type': 'mediumThreeByTwo210', 'src': 'https:...   2018-10-12
# 6  {'type': 'mediumThreeByTwo210', 'src': 'https:...         None
# 7  {'type': 'mediumThreeByTwo210', 'src': 'https:...   2018-10-05
# 8  {'type': 'mediumThreeByTwo210', 'src': 'https:...   2018-10-12
# 9  {'type': 'mediumThreeByTwo210', 'src': 'https:...         None
#
#   publication_date                                      summary_short
# 0       2018-10-16  Marielle Heller directs a true story of litera...
# 1       2018-10-16  Marilyn Ness’s documentary is dedicated to the...
# 2       2018-10-16  A documentary explores the life of the blues m...
# 3       2018-10-16  This documentary examines the global art marke...
# 4       2018-10-16  This documentary follows Rocío Molina, a cutti...
# 5       2018-10-11  Charles Ferguson delivers a comprehensive docu...
# 6       2018-10-11  It’s a film of scenes rather than of one unifi...
# 7       2018-10-11  Margarita Mamun endures injury and abuse in Ma...
# 8       2018-10-11  Maggie Gyllenhaal is riveting as a dissatisfie...
# 9       2018-10-11  This highly original feature is technically in...

# %% [markdown]
# ## How many unique critics are there?

# %%
pd.Series(data['critics']).unique()
# Out:
# KeyErrorTraceback (most recent call last)
# <ipython-input-12-ed507816e22f> in <module>()
# ----> 1 pd.Series(data['critics']).unique()
#
# KeyError: 'critics'

# %% [markdown]
# ## Create a new column for the review's url. Title the column 'review_url'

# %%
df['review_url']=[a['url'] for a in df['link']]
df.head(5)
# Out:
#            byline  critics_pick         date_updated  \
# 0      A.O. SCOTT             1  2018-10-17 02:44:23
# 1  BEN KENIGSBERG             1  2018-10-16 11:04:03
# 2     GLENN KENNY             1  2018-10-16 11:04:04
# 3      A.O. SCOTT             0  2018-10-16 16:08:03
# 4  BEN KENIGSBERG             0  2018-10-16 11:04:03
#
#                                      display_title  \
# 0                          Can You Ever Forgive Me
# 1                                       Charm City
# 2  Horn from the Heart: The Paul Butterfield Story
# 3                          The Price of Everything
# 4                                          Impulso
#
#                                             headline  \
# 0  Review: Melissa McCarthy Is Criminally Good in...
# 1  Review: ‘Charm City’ Vividly Captures the Stre...
# 2  Review: Paul Butterfield’s Story Is Told in ‘H...
# 3  Review: ‘The Price of Everything’ Asks $56 Bil...
# 4  Review: ‘Impulso’ Goes Backstage With a Flamen...
#
#                                                 link mpaa_rating  \
# 0  {'type': 'article', 'url': 'http://www.nytimes...           R
# 1  {'type': 'article', 'url': 'http://www.nytimes...
# 2  {'type': 'article', 'url': 'http://www.nytimes...
# 3  {'type': 'article', 'url': 'http://www.nytimes...
# 4  {'type': 'article', 'url': 'http://www.nytimes...
#
#                                           multimedia opening_date  \
# 0  {'type': 'mediumThreeByTwo210', 'src': 'https:...   2018-10-19
# 1  {'type': 'mediumThreeByTwo210', 'src': 'https:...   2018-04-22
# 2  {'type': 'mediumThreeByTwo210', 'src': 'https:...   2018-10-19
# 3  {'type': 'mediumThreeByTwo210', 'src': 'https:...   2018-10-19
# 4  {'type': 'mediumThreeByTwo210', 'src': 'https:...         None
#
#   publication_date                                      summary_short  \
# 0       2018-10-16  Marielle Heller directs a true story of litera...
# 1       2018-10-16  Marilyn Ness’s documentary is dedicated to the...
# 2       2018-10-16  A documentary explores the life of the blues m...
# 3       2018-10-16  This documentary examines the global art marke...
# 4       2018-10-16  This documentary follows Rocío Molina, a cutti...
#
#                                           review_url
# 0  http://www.nytimes.com/2018/10/16/movies/can-y...
# 1  http://www.nytimes.com/2018/10/16/movies/charm...
# 2  http://www.nytimes.com/2018/10/16/movies/horn-...
# 3  http://www.nytimes.com/2018/10/16/movies/the-p...
# 4  http://www.nytimes.com/2018/10/16/movies/impul...

# %% [markdown]
# ## How many results are in the file?

# %%
#Your code here

# %% [markdown]
# ## Summary
# Well done! Here you continued to gather practice extracting data from JSON files and transforming them into our standard tool of Pandas DataFrames.
